# %%
import pandas as pd
import glob, os

# %%
df = pd.read_csv("bro_bids_ses-1.csv", sep="\t", index_col=['Unnamed: 0'])

# %%
df.index.name = "ses-1"
df
# Out:
#          anat  fmap  func  runs_pe  runs_rest  runs_train
# ses-1
# sub-001     0     0     0        0          0           0
# sub-002     0     0     0        0          0           0
# sub-003     0     0     0        0          0           0
# sub-004     0     0     0        0          0           0
# sub-006     1     5     5        2          1           2
# sub-007     1     5     5        2          1           2
# sub-008     1     5     5        2          1           2
# sub-009     1     6     6        2          1           3
# sub-010     1     0     0        0          0           0
# sub-011     1     5     5        2          1           2
# sub-012     1     0     0        0          0           0
# sub-013     0     0     0        0          0           0
# sub-014     1     6     6        2          1           3
# sub-015     1     5     5        2          1           2
# sub-016     1     5     5        2          1           2
# ...
