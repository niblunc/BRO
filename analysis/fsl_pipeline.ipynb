# %% [markdown]
# # FSL Pipeline

# %%
import os, glob
from IPython.core import display as ICD
from subprocess import check_output
import subprocess
import pandas as pd
import re

pd.set_option('display.max_rows', 200)
pd.set_option('display.max_columns', None)

# %% [markdown]
# ## Check available data in preprocessed/

# %% [markdown]
# Example subject directory holding preprocessed data:
#
# `bids/derivatives/preprocessed/sub-001
# ├── anat
# ├── ses-1
# │   └── func
# │       └── motion_assessment
# │           └── motion_parameters
# └── ses-2
#     └── func
#         └── motion_assessment
#             └── motion_parameters`

# %% [markdown]
# ### Run the code below to view a report of the preprocessed/ folder

# %%
def check_files(dir_path, sub_id,session, data_dict):
    funcs = glob.glob(os.path.join(dir_path, sub_id, session, "func/*brain.nii.gz"))
    func_ct = len(funcs)
    data_dict[sub_id][session]["func_ct"] = func_ct

    anat = glob.glob(os.path.join(dir_path, sub_id, "anat/*"))
    anat_ct = len(anat) 
    data_dict[sub_id][session]["anat_ct"] = anat_ct


    exp = "{}_{}*.txt".format(sub_id, session)
    onsets = glob.glob('/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/onsets/output_onsets/%s'%exp)
    onset_ct = len(onsets)
    data_dict[sub_id][session]["onset_ct"] = onset_ct

    
    confounds = glob.glob(os.path.join(dir_path, sub_id, session, "func/motion_assessment/*.txt"))
    confound_ct = len(confounds) 
    data_dict[sub_id][session]["confound_ct"] = confound_ct

    
    mocos = glob.glob(os.path.join(dir_path, sub_id, session, "func/motion_assessment/motion_parameters/*.txt"))
    moco_ct = len(mocos) 
    data_dict[sub_id][session]["moco_ct"] = moco_ct

# %%
print("\n[INFO] BRO PREPROCESSED DATA REPORT \n")

preproc_path="/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed"
sessions = ['ses-1', 'ses-2']
data_dict = {}



for session in sessions:
    subjects = sorted(glob.glob(os.path.join(preproc_path, 'sub-*', session)))
    sub_ids = [x.split("/")[-2] for x in subjects]
    subjects_ct = len(subjects)
    print("[INFO] {} subjects found count: {}".format(session, subjects_ct))

    for sub_id in sub_ids:
        if sub_id not in data_dict:
            data_dict[sub_id] = {}
            
        if session not in data_dict[sub_id]:
            data_dict[sub_id][session] = {}
            
        
        check_files(preproc_path, sub_id, session, data_dict)

df = pd.concat({k: pd.DataFrame(v).T for k, v in data_dict.items()}, axis=0)

ses1_df = df.xs('ses-1', level=1)
ses1_good_df = ses1_df[(ses1_df.T != 0).all()]
ses1_empty_df = ses1_df[(ses1_df.T == 0).any()]



ses2_df = df.xs('ses-2', level=1)
ses2_good_df = ses2_df[(ses2_df.T != 0).all()]
ses2_empty_df = ses2_df[(ses2_df.T == 0).any()]


print("\n[INFO] session 1 ready subjects: {} \n{}".format(len(ses1_good_df.index.values),ses1_good_df.index.values))
ICD.display(ses1_good_df.head())
print("\n[INFO] session 1 need processing subjects: {} \n{}".format(len(ses1_empty_df.index.values),ses1_empty_df.index.values))
ICD.display(ses1_empty_df.head())
print("\n[INFO] session 2 ready subjects: {} \n{}".format(len(ses2_good_df.index.values),ses2_good_df.index.values))
ICD.display(ses2_good_df.head())
print("\n[INFO] session 2 need processing subjects: {} \n{}".format(len(ses2_empty_df.index.values),ses2_empty_df.index.values))
ICD.display(ses2_empty_df.head())
# Out:
# [INFO] BRO PREPROCESSED DATA REPORT
#
# [INFO] ses-1 subjects found count: 54
# [INFO] ses-2 subjects found count: 54
#
# [INFO] session 1 ready subjects: 23
# ['sub-020' 'sub-022' 'sub-025' 'sub-026' 'sub-028' 'sub-029' 'sub-030'
#  'sub-032' 'sub-033' 'sub-035' 'sub-036' 'sub-037' 'sub-038' 'sub-039'
#  'sub-040' 'sub-041' 'sub-043' 'sub-044' 'sub-045' 'sub-046' 'sub-047'
#  'sub-052' 'sub-053']
#          func_ct  anat_ct  onset_ct  confound_ct  moco_ct
# sub-020        3        1        18            6       19
# sub-022        5        1        36           10       31
# sub-025        5        1        36           10       31
# sub-026        5        1        36           10       31
# sub-028        5        1        36           10       31
# [INFO] session 1 need processing subjects: 31
# ['sub-001' 'sub-002' 'sub-003' 'sub-004' 'sub-006' 'sub-007' 'sub-008'
#  'sub-009' 'sub-010' 'sub-011' 'sub-012' 'sub-013' 'sub-014' 'sub-015'
#  'sub-016' 'sub-017' 'sub-018' 'sub-019' 'sub-021' 'sub-023' 'sub-027'
#  'sub-031' 'sub-034' 'sub-042' 'sub-048' 'sub-049' 'sub-050' 'sub-051'
#  'sub-054' 'sub-055' 'sub-056']
#          func_ct  anat_ct  onset_ct  confound_ct  moco_ct
# sub-001        0        1         0            0        0
# sub-002        0        1         0            0        0
# sub-003        5        1         0           10       31
# sub-004        5        1         0           10       31
# sub-006        0        0         0            0        0
# [INFO] session 2 ready subjects: 21
# ['sub-004' 'sub-022' 'sub-025' 'sub-026' 'sub-027' 'sub-028' 'sub-029'
#  'sub-030' 'sub-032' 'sub-033' 'sub-036' 'sub-038' 'sub-039' 'sub-040'
#  'sub-041' 'sub-044' 'sub-045' 'sub-046' 'sub-047' 'sub-052' 'sub-053']
#          func_ct  anat_ct  onset_ct  confound_ct  moco_ct
# sub-004        5        1        36           10       30
# sub-022        5        1        36           10       30
# sub-025        5        1        36           10       30
# sub-026        5        1        36           10       30
# sub-027        5        1        27           10       30
# [INFO] session 2 need processing subjects: 33
# ['sub-001' 'sub-002' 'sub-003' 'sub-006' 'sub-007' 'sub-008' 'sub-009'
#  'sub-010' 'sub-011' 'sub-012' 'sub-013' 'sub-014' 'sub-015' 'sub-016'
#  'sub-017' 'sub-018' 'sub-019' 'sub-020' 'sub-021' 'sub-023' 'sub-031'
#  'sub-034' 'sub-035' 'sub-037' 'sub-042' 'sub-043' 'sub-048' 'sub-049'
#  'sub-050' 'sub-051' 'sub-054' 'sub-055' 'sub-056']
#          func_ct  anat_ct  onset_ct  confound_ct  moco_ct
# sub-001        5        1         0           10       30
# sub-002        5        1         0           10       30
# sub-003        4        1         0            8       24
# sub-006        0        0         0            0        0
# sub-007        5        1         0           10       30

# %% [markdown]
# ## FSL level1 on Bro data

# %% [markdown]
# ### Write level 1 models
# * **Model designs:** [google drive link](https://docs.google.com/spreadsheets/d/1bj3it16jW8lASIGgL9TIAsg0x2XuOT1JL71rTaEJ3aw/edit#gid=1860969306)
# * **Design files on RENCI:** /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/design_files

# %%
def make_file(sub, sub_path, sess, main_dict, task, deriv_dir, design_file):
    print("[INFO] writing {} design file...".format(sub))
    
    fsf_template = os.path.join(deriv_dir,'design_files/%s'%design_file)
    #for sess_id in sessions:


    if task == "resting":
        pass

    else:
        for key in main_dict[sub]:
            if key != "ANAT":
                run = key
                #print(run)
                outpath = os.path.join(deriv_dir, 'preprocessed', sub,sess, 'analysis', "feat1")
                
                # if MAKE DIRS flag true
                if not os.path.exists(outpath):
                    os.makedirs(outpath)


                with open(fsf_template, 'r') as infile:
                    #print("Opening template file {}".format(fsf_template))
                    tempfsf = infile.read()

                    #  fill in tempfsf file with parameters
                    tempfsf = tempfsf.replace("OUTPUT", main_dict[sub][run]["OUTPUT"])
                    tempfsf = tempfsf.replace("FUNCTIONAL", main_dict[sub][run]["FUNC"])
                    tempfsf = tempfsf.replace("CONFOUND", main_dict[sub][run]['CONFOUND'])
                    tempfsf = tempfsf.replace("VOL", main_dict[sub][run]['VOL'])


                    # loop through keys in dict to find EVs and MOCOs
                    for key in main_dict[sub][run]:


                        # Fill in EVS
                        if re.match(r'EV', key):
                            ev_name= "{}_file".format(key.replace("EV_", ""))
                            ev = main_dict[sub][run][key]
                            tempfsf = tempfsf.replace(ev_name, ev)
                            #print(ev_name)
                        if re.match(r'moco', key):
                            moco_file = main_dict[sub][run][key]
                            moco_id = moco_file.split("/")[-1].split("_")[4].split(".")[0]+"_file"
                            tempfsf = tempfsf.replace(moco_id, moco_file)
                            #print(moco_id)

                    fsf_outfile = 'task-%s_run-%s.fsf' % (task,'{0:02d}'.format(int(run)) )
                    print(os.path.join(outpath, fsf_outfile))
                    #print(tempfsf)
                    with open(os.path.join(outpath, fsf_outfile), 'w') as outfile: #os.path.join(outpath,
                        outfile.write(tempfsf)
                    outfile.close()
                infile.close()

# %%
def fill_dict(sub, sub_path, main_dict, task, sess, evs, all_runs):
    
    
    #print("SUBJECT: %s \t TASK: %s \nPATH: %s"% (sub, task, sub_path))

    # only specified sessions
    #for sess_id in sessions:

    if task == 'resting':
        # case for no runs, only task (i.e. resting)
        pass
    else:
    # 2 cases: individual/given runs or all runs found

        # case 1: if flag false, grab all available runs found
        if all_runs == True:
            funcs_found = glob.glob(os.path.join(sub_path, 'func',
                                         "%s_%s_task-%s_run-*preproc*brain.nii.gz" % (sub,sess,task)))
            #print(funcs_found)
            runs=[x.split("/")[-1].split("_")[3].split("-")[1] for x in funcs_found]
            #print(runs)
            for run in runs:
                main_dict[sub][run] = {}
            #print("Dictionary initialized as: {}".format(main_dict[sub]))

            for func in funcs_found:
                x = int(run)
                run=func.split("/")[-1].split("_")[3].split("-")[1]
                #print(run)
                
                # SET OUTPUT PATH FOR FEAT DIRECTORY
                output_path=os.path.join(sub_path, 'analysis', 'feat1', 'task-%s_run-%s' %(task, run))


                # SET CONFOUND
                # sub-004_ses-2_task-training_run-2_space-MNI152NLin2009cAsym_desc-preproc_confound.txt

                confound = os.path.join(sub_path, 'func', 'motion_assessment',
                                 '%s_%s_task-%s_run-%s_space-MNI152NLin2009cAsym_desc-preproc_confound.txt'%(sub,sess, task, run))

                # SET ANAT
                #anat = os.path.join(sub_path.strip("{}/".format(sess)), 'anat', 'highres.nii.gz')





                # FILL DICTIONARY
                #main_dict[sub]['ANAT'] = anat
                main_dict[sub][run]['OUTPUT'] = output_path
                scan = func.split(".")[0]
                main_dict[sub][run]['FUNC'] = scan
                vol = check_output(['fslnvols', scan])
                vol = vol.decode('utf-8')
                vol = vol.strip('\n')
                main_dict[sub][run]['VOL'] = vol
                main_dict[sub][run]['CONFOUND'] = confound



                # TRS FROM NIFTI -- this value will always be 2, therefore we only run the check once
                trs = check_output(['fslval', '%s' % (scan), 'pixdim4', scan])
                trs = trs.decode('utf-8')
                trs = trs.strip('\n')
                # print("TRs: ", trs)

                main_dict[sub][run]['TR'] = trs


                # SET MOTION PARAMETERS
                for i in range(6):
                    motcor = os.path.join(sub_path, 'func', 'motion_assessment', 'motion_parameters',
                                      '%s_%s_task-%s_run-%s_moco%s.txt' % (sub, sess,task, run, i))
                    main_dict[sub][run]['moco%i' % i] = motcor


                # SET EVS
                # Loop through the given EVs and add the corresponding file to the dictionary

                ctr = 0
                onset_path = "/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/onsets/output_onsets"
                for ev_name in evs:
                    # print(item)
                    ctr = ctr + 1
                    #sub-037_ses-1_training_run-1_h2o.txt
                    ev = os.path.join(onset_path,  '%s_%s_task-%s_run-%s_%s.txt' % (sub, sess, task, run, ev_name))
                    
                    #print(ev)
                    # print("EV: ", ev)
                    main_dict[sub][run]['EV_%s' % ev_name] = ev

# %%
def setup_lvl1_design_files(sub_ids):
    #set_paths()
    
    # removed path function for now
    print("Starting program....")
    
    deriv_dir = "/projects/niblab/bids_projects/Experiments/bro/bids/derivatives"
    main_dict = {}
    run_bash = False
    write_file = False
    sess = "ses-2"
    
    
    
    
    
    if write_file == True:
        ## case: Get all subjects available --add flag for individual subjects or passed list option
        for sub in sub_ids:
            sub_path = os.path.join(deriv_dir,"preprocessed", sub, sess)
            design_file = "pe_design1.fsf"
            # set variables
            task = "pe"
            evs = ['milkshake_cue', 'milkshake_delivery', 'h2O_cue', 'h2O_delivery', 'rinse', 
                  'pe', 'matched_milkshake', 'matched_h2O', 'anticipation_milkshake']
            all_runs = True


            #set_dict(sub)

            if sub not in main_dict:
                main_dict[sub] = {}


            fill_dict(sub,sub_path, main_dict, task, sess, evs, all_runs)
            #print(main_dict['sub-004'])
            make_file(sub, sub_path, sess, main_dict, task, deriv_dir, design_file)
            #make_file(sub, main_dict, task, deriv_dir, fsf_template)
    

    if run_bash == True:
        
        subject_set = sorted([int(x.split("-")[1].lstrip("0")) for x in sub_ids])
        print(subject_set)
        bash_file = os.path.join('/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code', 'feat1.job')
        start = subject_set[0]
        end = subject_set[-1]
        #print(start, end)
        #for sub_num in subject_set:
        shell_cmd = "sbatch --array={}-{}%{} {}".format(start, end, len(subject_set), bash_file)
        os.system(shell_cmd)
        print(shell_cmd)

# %% [markdown]
# ### Run files

# %%
sub_ids = ses2_good_df.index.values
setup_lvl1_design_files(sub_ids)
# Out:
# Starting program....
# [4, 22, 25, 26, 27, 28, 29, 30, 32, 33, 36, 38, 39, 40, 41, 44, 45, 46, 47, 52, 53]
# sbatch --array=4-53%21 /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code/feat1.job

# %%
# !squeue -u nbytes
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)

# %% [markdown]
# ## Quality Check level 1 models

# %%
qc_dict={}
df_dict={}
lvl1_zstat_dict={}
errors=[]

print("[INFO] running quality check...")
for sess in ['ses-1', 'ses-2']:
    for sub_id in ses1_df.index.values:
        sub_path = os.path.join("/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/{}/{}".format(sub_id, sess))
        # set per subject variables

        #sub_id=sub_path.split("/")[-1]

        if sub_id not in qc_dict:
            qc_dict[sub_id] = {}
        if sub_id not in lvl1_zstat_dict:
            lvl1_zstat_dict[sub_id] = {}
        if sess not in lvl1_zstat_dict[sub_id]:
            lvl1_zstat_dict[sub_id][sess] = {}
            
            
        feat1_path = os.path.join(sub_path, "analysis/feat1")
        feat1_folders = sorted(glob.glob(os.path.join(feat1_path, "*.feat")))

        mean_func_ct=0

        for run_folder in feat1_folders:

            # set per run variables

            run_id = run_folder.split("/")[-1].split("_")[1].split(".")[0]
            task_id =  run_folder.split("/")[-1].split("_")[0].split(".")[0]
            
            
            
            zstats=glob.glob(os.path.join(run_folder, 'stats/zstat*nii.gz'))
            filtered_func = os.path.join(run_folder, "filtered_func_data.nii.gz")
            zstat1 = os.path.join(run_folder, "stats/zstat1.nii.gz")
            zstats_ct = len(zstats)
            #print(run_id)


            # CHECK FOR MISSING ZSTATS        
            if not zstats:
                #print("MISSING ZSTATS: {}\t{}".format(sub_path.split("/")[-1], run_id))
                errors.append((sub_id, run_id))
                # ADD REPORT 

            else:
                for zstat_file in zstats:
                    
                    zstat=zstat_file.split("/")[-1].split(".")[0]
                    zstat= "%s_%s_%s"%(task_id, run_id, zstat)
                        
                    cmd='fslstats %s -R'%zstat_file
                    #print(cmd)
                    process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
                    output, error = process.communicate()              
                    output=output.decode("utf-8")
                    output=output.strip("\n")
                    lvl1_zstat_dict[sub_id][sess][zstat] = output
                


            # UPDATE DICTIONARY 
            if run_id == "run-1":
                qc_dict[sub_id]["r1_zstat_ct"] = zstats_ct
            elif run_id == "run-2":
                qc_dict[sub_id]["r2_zstat_ct"] = zstats_ct
      
            #qc_dict[sub_id][run_id]["max_vox"]=max_vox



    print("[INFO] Session: ", sess)
    df = pd.DataFrame(qc_dict).T.fillna(0)
    #display(df)
    print("\n[INFO] Good subjects: \n")
    print(df[(df.T != 0).all()].index.values)
    print("\n[INFO] Subjects missing zstat files: \n")
    print(df[(df.T == 0).any()].index.values)
    df_dict[sess] = df
#for err in errors:
    #check_error_dir(err, deriv_path)
# Out:
# [INFO] running quality check...
# [INFO] Session:  ses-1
#
# [INFO] Good subjects:
#
# ['sub-022' 'sub-025' 'sub-026' 'sub-028' 'sub-029' 'sub-030' 'sub-032'
#  'sub-033' 'sub-035' 'sub-036' 'sub-038' 'sub-039' 'sub-040' 'sub-041'
#  'sub-043' 'sub-044' 'sub-045' 'sub-046' 'sub-047' 'sub-052' 'sub-053']
#
# [INFO] Subjects missing zstat files:
#
# ['sub-001' 'sub-002' 'sub-003' 'sub-004' 'sub-006' 'sub-007' 'sub-008'
#  'sub-009' 'sub-010' 'sub-011' 'sub-012' 'sub-013' 'sub-014' 'sub-015'
#  'sub-016' 'sub-017' 'sub-018' 'sub-019' 'sub-020' 'sub-021' 'sub-023'
#  'sub-027' 'sub-031' 'sub-034' 'sub-037' 'sub-042' 'sub-048' 'sub-049'
#  'sub-050' 'sub-051' 'sub-054' 'sub-055' 'sub-056']
# [INFO] Session:  ses-2
#
# [INFO] Good subjects:
#
# ['sub-004' 'sub-022' 'sub-025' 'sub-026' 'sub-027' 'sub-028' 'sub-029'
#  'sub-030' 'sub-032' 'sub-033' 'sub-035' 'sub-036' 'sub-038' 'sub-039'
#  'sub-040' 'sub-041' 'sub-043' 'sub-044' 'sub-045' 'sub-046' 'sub-047'
#  'sub-052' 'sub-053']
#
# [INFO] Subjects missing zstat files:
#
# ['sub-001' 'sub-002' 'sub-003' 'sub-006' 'sub-007' 'sub-008' 'sub-009'
#  'sub-010' 'sub-011' 'sub-012' 'sub-013' 'sub-014' 'sub-015' 'sub-016'
#  'sub-017' 'sub-018' 'sub-019' 'sub-020' 'sub-021' 'sub-023' 'sub-031'
#  'sub-034' 'sub-037' 'sub-042' 'sub-048' 'sub-049' 'sub-050' 'sub-051'
#  'sub-054' 'sub-055' 'sub-056']

# %%
lvl1_zstat_df =pd.concat({k: pd.DataFrame(v).T for k, v in lvl1_zstat_dict.items()}, axis=0)
# Out:
# /home/nbytes/modules/software/miniconda3/3.0.0/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
# write dataframe to excel
#lvl1_zstat_df.to_excel('lvl1_zstat_voxel_check.xlsx')


# view level1 zstat voxel check values -- 'fslstats zstat.nii.gz'
tasks=["task-training", "task-pe"]
for task in tasks:
    print("\n[INFO] view zstat voxel check report for feat1 %s models... \n\n"%task)
    display(lvl1_zstat_df.filter(regex=("%s*"%task)))
# Out:
# [INFO] view zstat voxel check report for feat1 task-training models...
#               task-training_run-1_zstat1 task-training_run-1_zstat10  \
# sub-001 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-002 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-003 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-004 ses-1                        NaN                         NaN
#         ses-2        -3.602966 3.500740          -3.405648 3.178697
# sub-006 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-007 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-008 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-009 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-010 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-011 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-012 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-013 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-014 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-015 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-016 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-017 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-018 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-019 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-020 ses-1        -3.557963 3.837220          -4.373131 3.338670
#         ses-2                        NaN                         NaN
# sub-021 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-022 ses-1        -3.449903 3.479149          -3.800173 4.439355
#         ses-2        -4.908182 5.458394          -4.323241 5.162174
# sub-023 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-025 ses-1        -3.333854 3.848979          -4.685764 3.897273
#         ses-2        -3.272327 4.215624          -4.634315 3.767376
# sub-026 ses-1        -3.741002 4.385347          -4.198166 5.094502
#         ses-2        -3.569800 4.135463          -3.724078 3.432607
# sub-027 ses-1                        NaN                         NaN
#         ses-2        -5.295704 4.964315          -3.791232 4.805644
# sub-028 ses-1        -3.867210 3.741740          -3.844896 3.766671
#         ses-2        -4.710293 3.957121          -3.677935 3.566500
# sub-029 ses-1        -4.446853 4.504173          -4.163663 6.562389
#         ses-2        -3.679922 4.647163          -3.486717 5.479066
# sub-030 ses-1        -3.730778 5.481168          -4.275014 5.350660
#         ses-2        -4.713498 3.420904          -3.806956 3.848237
# sub-031 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-032 ses-1        -4.967711 4.778669          -5.721502 5.236395
#         ses-2        -3.822144 3.455301          -4.315887 4.394715
# sub-033 ses-1        -5.060844 4.777277          -4.053003 4.685021
#         ses-2        -3.729268 3.977215          -4.447987 4.055737
# sub-034 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-035 ses-1        -4.082218 4.521800          -4.457358 4.725677
#         ses-2                        NaN                         NaN
# sub-036 ses-1        -3.989567 4.217969          -3.971089 4.122470
#         ses-2        -3.678180 4.245924          -4.089894 4.119621
# sub-037 ses-1        -4.202197 5.860998          -4.694135 6.647086
#         ses-2                        NaN                         NaN
# sub-038 ses-1        -3.463486 4.348956          -3.380782 3.713531
#         ses-2        -3.589536 3.814284          -3.584412 3.859894
# sub-039 ses-1        -4.526271 3.617482          -3.576911 4.104718
#         ses-2        -3.504886 3.794318          -3.968641 4.081772
# sub-040 ses-1        -4.297637 5.167043          -3.653746 5.022450
#         ses-2        -5.051114 3.785902          -4.175813 3.469845
# sub-041 ses-1        -3.798472 4.280150          -4.319421 4.783576
#         ses-2        -3.336727 3.318015          -3.263692 4.116374
# sub-042 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-043 ses-1        -4.591800 4.617752          -4.382888 4.805054
#         ses-2                        NaN                         NaN
# sub-044 ses-1        -3.865937 3.664560          -4.147262 3.462221
#         ses-2        -4.361431 4.340754          -3.809553 3.414388
# sub-045 ses-1        -3.969932 4.632393          -4.478031 4.374676
#         ses-2        -3.363118 3.774080          -3.722105 4.235672
# sub-046 ses-1        -3.512644 3.906578          -3.909629 3.690400
#         ses-2        -4.036383 3.663211          -3.673418 4.805646
# sub-047 ses-1        -3.796815 4.262952          -4.114496 3.221393
#         ses-2        -3.828858 3.598915          -4.827836 3.932205
# sub-048 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-049 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-050 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-051 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-052 ses-1        -3.692147 4.754816          -4.134694 6.221380
#         ses-2        -4.089007 4.006045          -4.981994 4.413568
# sub-053 ses-1        -3.732705 4.119232          -3.365072 4.451309
#         ses-2        -2.937236 4.472379          -3.498633 3.988683
# sub-054 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-055 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-056 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
#
#               task-training_run-1_zstat2 task-training_run-1_zstat3  \
# sub-001 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-002 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-003 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-004 ses-1                        NaN                        NaN
#         ses-2        -4.044909 3.461496         -3.634989 3.207938
# sub-006 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-007 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-008 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-009 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-010 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-011 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-012 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-013 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-014 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-015 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-016 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-017 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-018 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-019 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-020 ses-1        -3.980931 3.956065         -4.397611 3.534676
#         ses-2                        NaN                        NaN
# sub-021 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-022 ses-1        -3.604006 3.931909         -3.826132 4.360144
#         ses-2        -7.571221 4.444529         -4.454917 4.817848
# sub-023 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-025 ses-1        -3.923587 3.658523         -5.119547 4.010272
#         ses-2        -4.657413 3.573650         -4.367233 3.827435
# sub-026 ses-1        -4.006474 4.335351         -4.226688 5.052488
#         ses-2        -3.903991 3.246156         -3.790306 3.461608
# sub-027 ses-1                        NaN                        NaN
#         ses-2        -4.949413 5.586698         -3.737133 4.805993
# sub-028 ses-1        -4.406968 4.054682         -3.940929 3.812313
#         ses-2        -4.469357 4.188274         -3.754393 3.592685
# sub-029 ses-1        -4.761001 4.060439         -3.778430 6.388833
#         ses-2        -4.868694 3.713522         -3.284007 5.267255
# sub-030 ses-1        -4.533918 4.244964         -4.259766 5.637913
#         ses-2        -3.326196 4.606510         -3.993442 3.844341
# sub-031 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-032 ses-1        -5.857229 4.579896         -5.495582 5.056570
#         ses-2        -3.616391 3.987807         -4.253092 4.430717
# sub-033 ses-1        -4.938597 4.258592         -4.131534 4.970405
#         ses-2        -4.858686 3.933046         -4.578744 4.096731
# sub-034 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-035 ses-1        -4.026510 4.008605         -4.494484 4.711729
#         ses-2                        NaN                        NaN
# sub-036 ses-1        -4.339025 3.372335         -4.039053 4.621284
#         ses-2        -3.969786 3.885231         -4.163823 4.555469
# sub-037 ses-1        -4.952796 3.334762         -4.387462 6.919647
#         ses-2                        NaN                        NaN
# sub-038 ses-1        -4.103230 3.388286         -3.501607 3.650579
#         ses-2        -3.740666 3.825937         -3.443862 4.020513
# sub-039 ses-1        -4.007735 3.765761         -3.501786 4.331247
#         ses-2        -4.226908 4.041929         -4.195148 4.126682
# sub-040 ses-1        -5.469115 4.250359         -3.611596 5.030069
#         ses-2        -3.288054 4.229382         -4.425360 3.711371
# sub-041 ses-1        -4.353316 4.138196         -4.115432 4.586933
#         ses-2        -3.284720 3.497895         -3.219425 4.103498
# sub-042 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-043 ses-1        -4.334755 4.382312         -4.491588 4.775465
#         ses-2                        NaN                        NaN
# sub-044 ses-1        -3.709046 4.215570         -4.147143 3.655131
#         ses-2        -4.040834 4.150264         -4.024648 3.415922
# sub-045 ses-1        -5.762393 3.987752         -4.671355 4.353711
#         ses-2        -3.872315 3.818595         -3.758225 4.440476
# sub-046 ses-1        -3.750435 4.110093         -3.835586 3.695384
#         ses-2        -3.766706 3.559597         -3.843175 4.624322
# sub-047 ses-1        -4.050967 3.499734         -4.357082 3.199746
#         ses-2        -3.916986 3.723321         -4.691031 3.841635
# sub-048 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-049 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-050 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-051 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-052 ses-1        -6.072413 3.968634         -4.125073 6.256988
#         ses-2        -4.032880 3.777207         -5.059942 4.355958
# sub-053 ses-1        -3.361990 4.256747         -3.322646 4.488787
#         ses-2        -3.964449 3.640619         -3.755065 3.996621
# sub-054 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-055 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-056 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
#
#               task-training_run-1_zstat4 task-training_run-1_zstat5  \
# sub-001 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-002 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-003 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-004 ses-1                        NaN                        NaN
#         ses-2        -3.143607 3.355487         -5.293310 4.835000
# sub-006 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-007 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-008 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-009 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-010 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-011 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-012 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-013 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-014 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-015 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-016 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-017 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-018 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-019 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-020 ses-1        -3.554568 3.917418         -5.861248 5.360714
#         ses-2                        NaN                        NaN
# sub-021 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-022 ses-1        -4.195050 3.894870         -3.839233 5.457257
#         ses-2        -6.595562 4.423409         -5.855515 6.151558
# sub-023 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-025 ses-1        -4.200509 4.797766         -6.873796 6.714309
#         ses-2        -4.463266 4.729540         -5.084959 6.148293
# sub-026 ses-1        -4.417696 4.101750         -4.873806 4.356979
#         ses-2        -3.210465 4.046465         -3.882125 4.459753
# sub-027 ses-1                        NaN                        NaN
#         ses-2        -4.386229 4.672462         -4.983121 6.464635
# sub-028 ses-1        -4.256245 3.778861         -6.166211 4.076058
#         ses-2        -4.117516 4.157510         -4.985978 4.709408
# sub-029 ses-1        -5.646382 4.349168         -6.797548 5.547231
#         ses-2        -5.053880 3.392775         -5.000139 5.112534
# sub-030 ses-1        -4.978966 3.764088         -4.927382 5.588647
#         ses-2        -3.961969 3.416757         -4.889945 4.764833
# sub-031 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-032 ses-1        -4.969059 4.722375         -6.561350 4.495203
#         ses-2        -4.637926 4.405869         -5.069749 4.696409
# sub-033 ses-1        -4.061141 3.764361         -5.921699 4.320379
#         ses-2        -5.871446 4.239242         -6.153759 4.552483
# sub-034 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-035 ses-1        -4.580540 4.325822         -4.860102 5.360561
#         ses-2                        NaN                        NaN
# sub-036 ses-1        -4.615162 3.628278         -5.491648 5.923479
#         ses-2        -4.099647 4.451265         -4.770854 7.160024
# sub-037 ses-1        -4.680160 4.164850         -5.151845 7.648236
#         ses-2                        NaN                        NaN
# sub-038 ses-1        -3.438489 3.228926         -4.123735 3.826237
#         ses-2        -3.559308 3.599272         -3.777601 4.532137
# sub-039 ses-1        -5.260242 3.303878         -4.876535 4.800980
#         ses-2        -4.218753 4.110523         -4.580290 4.511196
# sub-040 ses-1        -4.692059 3.970612         -4.947198 5.124863
#         ses-2        -3.722249 3.590216         -5.196157 4.706535
# sub-041 ses-1        -4.529137 4.145827         -5.778653 5.251863
#         ses-2        -4.122022 3.410140         -4.346060 4.729442
# sub-042 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-043 ses-1        -4.768095 3.834397         -4.518949 6.822384
#         ses-2                        NaN                        NaN
# sub-044 ses-1        -4.047579 3.655648         -4.639274 4.661469
#         ses-2        -3.650978 3.933280         -4.974344 4.455459
# sub-045 ses-1        -5.185393 4.590780         -5.401656 5.271310
#         ses-2        -3.660824 3.939562         -4.332118 4.992301
# sub-046 ses-1        -3.615399 3.543586         -5.411482 4.383151
#         ses-2        -5.988721 3.197348         -5.538523 5.003664
# sub-047 ses-1        -3.634830 4.223763         -4.869905 4.033367
#         ses-2        -4.413223 3.699163         -4.272010 3.462263
# sub-048 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-049 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-050 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-051 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-052 ses-1        -5.562429 3.627593         -7.640261 5.766986
#         ses-2        -4.304957 4.373512         -3.979015 5.258431
# sub-053 ses-1        -4.517384 4.124688         -5.063534 5.490818
#         ses-2        -4.276320 3.399514         -4.703373 4.533358
# sub-054 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-055 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-056 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
#
#               task-training_run-1_zstat6 task-training_run-1_zstat7  \
# sub-001 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-002 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-003 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-004 ses-1                        NaN                        NaN
#         ses-2        -3.147582 3.338459         -3.484410 3.133833
# sub-006 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-007 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-008 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-009 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-010 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-011 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-012 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-013 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-014 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-015 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-016 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-017 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-018 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-019 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-020 ses-1        -3.941308 4.347508         -4.284496 3.660292
#         ses-2                        NaN                        NaN
# sub-021 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-022 ses-1        -3.862685 3.522132         -3.646237 3.666936
#         ses-2        -4.551984 3.989691         -4.054762 4.908579
# sub-023 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-025 ses-1        -3.865689 3.918957         -4.464808 4.100201
#         ses-2        -3.084831 4.413154         -4.297641 3.282996
# sub-026 ses-1        -4.675479 4.180891         -4.019515 4.813971
#         ses-2        -3.997734 4.960526         -5.115588 4.008487
# sub-027 ses-1                        NaN                        NaN
#         ses-2        -4.406649 4.410789         -4.428101 4.433211
# sub-028 ses-1        -4.246818 4.071032         -3.984276 4.294080
#         ses-2        -4.387087 3.824810         -3.795702 3.952702
# sub-029 ses-1        -4.316220 3.908981         -3.888107 4.550810
#         ses-2        -3.725716 3.697092         -3.632366 3.848546
# sub-030 ses-1        -4.100001 3.741194         -3.752083 4.773037
#         ses-2        -4.005054 3.596746         -3.989426 3.931195
# sub-031 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-032 ses-1        -3.789352 3.547883         -3.542382 4.120420
#         ses-2        -4.180951 4.247439         -4.178819 4.617743
# sub-033 ses-1        -4.032510 3.656184         -3.610231 4.079167
#         ses-2        -4.459278 4.078447         -4.058309 4.404482
# sub-034 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-035 ses-1        -3.726162 3.995008         -3.972384 4.183005
#         ses-2                        NaN                        NaN
# sub-036 ses-1        -3.942146 3.521927         -3.744396 4.148491
#         ses-2        -3.658872 3.811829         -4.140662 3.991980
# sub-037 ses-1        -3.819028 4.250344         -4.025130 3.858009
#         ses-2                        NaN                        NaN
# sub-038 ses-1        -3.739482 4.238523         -4.531615 3.785778
#         ses-2        -3.392860 3.711394         -3.459527 3.365164
# sub-039 ses-1        -4.724614 4.033697         -3.946663 4.602739
#         ses-2        -3.165608 3.716181         -3.853352 2.939679
# sub-040 ses-1        -3.857926 3.841067         -3.951045 3.977789
#         ses-2        -4.198270 3.610029         -3.596999 4.076596
# sub-041 ses-1        -4.765539 4.503711         -4.376764 4.577451
#         ses-2        -3.257299 3.814594         -3.999247 3.888902
# sub-042 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-043 ses-1        -4.024883 3.685465         -4.006817 3.986510
#         ses-2                        NaN                        NaN
# sub-044 ses-1        -4.107284 3.996093         -3.781773 4.439523
#         ses-2        -3.794826 3.819800         -3.783227 4.026064
# sub-045 ses-1        -4.029999 4.244834         -4.154129 4.046522
#         ses-2        -4.285686 3.506682         -3.443847 3.678101
# sub-046 ses-1        -2.720681 3.335230         -3.191652 3.346474
#         ses-2        -4.336767 3.309712         -3.083879 4.221059
# sub-047 ses-1        -3.683796 4.680632         -4.161307 3.864032
#         ses-2        -4.206990 3.871657         -3.407348 4.059549
# sub-048 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-049 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-050 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-051 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-052 ses-1        -4.159276 3.854468         -3.709471 4.613404
#         ses-2        -3.657102 4.625379         -4.858143 3.550308
# sub-053 ses-1        -4.716149 3.711497         -3.673338 4.625628
#         ses-2        -3.427680 3.953476         -4.122992 3.481096
# sub-054 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-055 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-056 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
#
#               task-training_run-1_zstat8 task-training_run-1_zstat9  \
# sub-001 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-002 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-003 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-004 ses-1                        NaN                        NaN
#         ses-2        -3.338459 3.147582         -3.133833 3.484410
# sub-006 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-007 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-008 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-009 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-010 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-011 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-012 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-013 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-014 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-015 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-016 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-017 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-018 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-019 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-020 ses-1        -4.347508 3.941308         -3.660292 4.284496
#         ses-2                        NaN                        NaN
# sub-021 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-022 ses-1        -3.522132 3.862685         -3.666936 3.646237
#         ses-2        -3.989691 4.551984         -4.908579 4.054762
# sub-023 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-025 ses-1        -3.918957 3.865689         -4.100201 4.464808
#         ses-2        -4.413154 3.084831         -3.282996 4.297641
# sub-026 ses-1        -4.180891 4.675479         -4.813971 4.019515
#         ses-2        -4.960526 3.997734         -4.008487 5.115588
# sub-027 ses-1                        NaN                        NaN
#         ses-2        -4.410789 4.406649         -4.433211 4.428101
# sub-028 ses-1        -4.071032 4.246818         -4.294080 3.984276
#         ses-2        -3.824810 4.387087         -3.952702 3.795702
# sub-029 ses-1        -3.908981 4.316220         -4.550810 3.888107
#         ses-2        -3.697092 3.725716         -3.848546 3.632366
# sub-030 ses-1        -3.741194 4.100001         -4.773037 3.752083
#         ses-2        -3.596746 4.005054         -3.931195 3.989426
# sub-031 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-032 ses-1        -3.547883 3.789352         -4.120420 3.542382
#         ses-2        -4.247439 4.180951         -4.617743 4.178819
# sub-033 ses-1        -3.656184 4.032510         -4.079167 3.610231
#         ses-2        -4.078447 4.459278         -4.404482 4.058309
# sub-034 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-035 ses-1        -3.995008 3.726162         -4.183005 3.972384
#         ses-2                        NaN                        NaN
# sub-036 ses-1        -3.521927 3.942146         -4.148491 3.744396
#         ses-2        -3.811829 3.658872         -3.991980 4.140662
# sub-037 ses-1        -4.250344 3.819028         -3.858009 4.025130
#         ses-2                        NaN                        NaN
# sub-038 ses-1        -4.238523 3.739482         -3.785778 4.531615
#         ses-2        -3.711394 3.392860         -3.365164 3.459527
# sub-039 ses-1        -4.033697 4.724614         -4.602739 3.946663
#         ses-2        -3.716181 3.165608         -2.939679 3.853352
# sub-040 ses-1        -3.841067 3.857926         -3.977789 3.951045
#         ses-2        -3.610029 4.198270         -4.076596 3.596999
# sub-041 ses-1        -4.503711 4.765539         -4.577451 4.376764
#         ses-2        -3.814594 3.257299         -3.888902 3.999247
# sub-042 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-043 ses-1        -3.685465 4.024883         -3.986510 4.006817
#         ses-2                        NaN                        NaN
# sub-044 ses-1        -3.996093 4.107284         -4.439523 3.781773
#         ses-2        -3.819800 3.794826         -4.026064 3.783227
# sub-045 ses-1        -4.244834 4.029999         -4.046522 4.154129
#         ses-2        -3.506682 4.285686         -3.678101 3.443847
# sub-046 ses-1        -3.335230 2.720681         -3.346474 3.191652
#         ses-2        -3.309712 4.336767         -4.221059 3.083879
# sub-047 ses-1        -4.680632 3.683796         -3.864032 4.161307
#         ses-2        -3.871657 4.206990         -4.059549 3.407348
# sub-048 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-049 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-050 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-051 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-052 ses-1        -3.854468 4.159276         -4.613404 3.709471
#         ses-2        -4.625379 3.657102         -3.550308 4.858143
# sub-053 ses-1        -3.711497 4.716149         -4.625628 3.673338
#         ses-2        -3.953476 3.427680         -3.481096 4.122992
# sub-054 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-055 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-056 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
#
#               task-training_run-2_zstat1 task-training_run-2_zstat10  \
# sub-001 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-002 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-003 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-004 ses-1                        NaN                         NaN
#         ses-2        -3.692647 3.597711          -2.739727 3.429365
# sub-006 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-007 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-008 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-009 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-010 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-011 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-012 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-013 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-014 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-015 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-016 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-017 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-018 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-019 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-020 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-021 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-022 ses-1        -4.395403 3.453381          -4.858195 5.088156
#         ses-2        -4.779060 4.548729          -5.468682 4.219890
# sub-023 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-025 ses-1        -3.995342 3.312896          -4.086188 4.227326
#         ses-2        -4.008610 3.598059          -4.387739 3.654007
# sub-026 ses-1        -3.897848 3.799630          -3.941112 4.146103
#         ses-2        -4.163455 4.913144          -3.666321 4.122136
# sub-027 ses-1                        NaN                         NaN
#         ses-2        -4.542499 3.410046          -3.729536 4.474207
# sub-028 ses-1        -4.024304 3.670002          -3.551655 3.650094
#         ses-2        -4.510155 3.448055          -3.983431 4.286533
# sub-029 ses-1        -4.082543 4.586682          -4.232980 5.433943
#         ses-2        -4.752448 4.047654          -4.153385 6.240119
# sub-030 ses-1        -4.878380 4.959880          -4.565168 4.512575
#         ses-2        -4.118087 4.271081          -3.909794 4.818204
# sub-031 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-032 ses-1        -4.488886 4.304427          -4.551022 4.159479
#         ses-2        -4.479019 4.416120          -4.144720 4.432775
# sub-033 ses-1        -3.988936 3.423774          -4.558675 3.665004
#         ses-2        -3.582859 3.941770          -4.418463 3.973465
# sub-034 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-035 ses-1        -4.032715 3.975883          -3.841387 4.990585
#         ses-2                        NaN                         NaN
# sub-036 ses-1        -4.181807 4.175185          -4.175777 4.459461
#         ses-2        -3.793358 3.980122          -3.709527 3.319922
# sub-037 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-038 ses-1        -4.363975 4.009575          -3.772149 4.387409
#         ses-2        -3.833337 3.453325          -4.272484 3.506439
# sub-039 ses-1        -3.881814 3.275680          -3.579120 3.671322
#         ses-2        -3.258384 3.527840          -3.873117 3.663562
# sub-040 ses-1        -3.460151 3.144190          -2.888234 3.109844
#         ses-2        -3.751795 3.438247          -4.383754 3.598326
# sub-041 ses-1        -3.543634 3.784954          -3.673175 3.710121
#         ses-2        -4.432352 3.147177          -4.164289 3.205622
# sub-042 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-043 ses-1        -4.519873 4.105009          -4.358891 4.219112
#         ses-2                        NaN                         NaN
# sub-044 ses-1        -3.599098 3.647019          -4.112448 4.297147
#         ses-2        -4.765602 3.645635          -4.319520 4.364839
# sub-045 ses-1        -4.177101 4.115845          -4.705718 3.499370
#         ses-2        -4.558786 5.097437          -4.448754 4.811736
# sub-046 ses-1        -3.999887 3.793115          -3.897077 3.668533
#         ses-2        -3.566734 3.284161          -4.417210 4.007671
# sub-047 ses-1        -4.531972 4.023367          -4.349283 4.082300
#         ses-2        -4.287241 4.254513          -3.489586 3.892659
# sub-048 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-049 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-050 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-051 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-052 ses-1        -3.924820 4.277066          -3.876780 5.954563
#         ses-2        -4.611981 4.451636          -3.957050 4.391406
# sub-053 ses-1        -4.082602 3.664946          -3.614799 3.326865
#         ses-2        -3.271576 4.151889          -3.482569 3.861505
# sub-054 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-055 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
# sub-056 ses-1                        NaN                         NaN
#         ses-2                        NaN                         NaN
#
#               task-training_run-2_zstat2 task-training_run-2_zstat3  \
# sub-001 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-002 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-003 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-004 ses-1                        NaN                        NaN
#         ses-2        -3.246292 3.491693         -3.025550 3.639850
# sub-006 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-007 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-008 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# sub-009 ses-1                        NaN                        NaN
#         ses-2                        NaN                        NaN
# ...
# sub-037 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-038 ses-1  -3.806945 3.165148   -4.196826 4.287711   -4.305929 4.219790
#         ses-2  -3.280749 4.492167   -3.901685 4.487316   -4.492702 3.895132
# sub-039 ses-1  -4.253534 3.766158   -3.306630 3.808838   -4.568566 6.031282
#         ses-2  -3.823750 3.809979   -4.383327 3.845813   -5.501848 4.517446
# sub-040 ses-1  -3.334978 3.804410   -3.805753 3.750332   -4.025193 4.369475
#         ses-2  -4.195222 3.555209   -3.530347 3.496003   -3.746430 5.176081
# sub-041 ses-1  -2.428875 3.261907   -4.053964 4.001621   -4.061471 4.306037
#         ses-2  -4.474962 3.633170   -3.769800 4.254141   -5.171963 4.678275
# sub-042 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-043 ses-1  -4.220471 3.904918   -4.226439 4.295712   -5.211134 6.222740
#         ses-2                  NaN                  NaN                  NaN
# sub-044 ses-1  -3.606831 4.069995   -3.005171 3.185538   -4.066513 4.044502
#         ses-2  -3.228987 3.927506   -3.401543 4.432322   -4.815458 3.987475
# sub-045 ses-1  -4.145292 3.936201   -3.986958 4.189888   -4.744930 4.950191
#         ses-2  -4.663707 4.728928   -5.058814 4.314570   -6.453929 5.988256
# sub-046 ses-1  -4.081029 3.548985   -4.286820 4.134548   -4.480071 4.407498
#         ses-2  -4.112401 4.595116   -3.817546 3.814033   -5.225631 5.477112
# sub-047 ses-1  -4.185269 3.772529   -4.130495 3.643657   -5.203888 3.951952
#         ses-2  -3.467208 3.738321   -3.943299 3.721205   -4.652670 5.089947
# sub-048 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-049 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-050 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-051 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-052 ses-1                  NaN                  NaN                  NaN
#         ses-2  -3.905487 4.152508   -4.263994 4.810499   -4.596699 5.361840
# sub-053 ses-1  -5.387561 3.870722   -3.186919 4.283350   -4.069660 4.413867
#         ses-2  -4.586090 3.644530   -3.569546 3.314516   -3.958112 5.493881
# sub-054 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-055 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-056 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
#
#               task-pe_run-2_zstat6 task-pe_run-2_zstat7 task-pe_run-2_zstat8  \
# sub-001 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-002 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-003 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-004 ses-1                  NaN                  NaN                  NaN
#         ses-2  -2.843759 3.566491   -4.443163 3.789935   -3.566491 2.843759
# sub-006 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-007 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-008 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-009 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-010 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-011 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-012 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-013 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-014 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-015 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-016 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-017 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-018 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-019 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-020 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-021 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-022 ses-1  -4.260676 4.085602   -4.792962 4.124205   -4.085602 4.260676
#         ses-2  -3.865671 3.789781   -3.790965 3.835413   -3.789781 3.865671
# sub-023 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-025 ses-1  -4.650855 3.185717   -3.977311 4.009985   -3.185717 4.650855
#         ses-2  -4.243677 4.290024   -3.440511 3.326349   -4.290024 4.243677
# sub-026 ses-1  -4.038123 4.476542   -3.847307 4.069550   -4.476542 4.038123
#         ses-2  -3.293261 3.395985   -5.204559 4.484983   -3.395985 3.293261
# sub-027 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-028 ses-1  -3.665130 4.282026   -4.166442 3.772550   -4.282026 3.665130
#         ses-2                  NaN                  NaN                  NaN
# sub-029 ses-1  -4.786750 3.974526   -4.480811 3.263979   -3.974526 4.786750
#         ses-2  -3.774485 3.844688   -3.639904 4.670918   -3.844688 3.774485
# sub-030 ses-1  -3.510977 3.425847   -4.433038 3.309891   -3.425847 3.510977
#         ses-2  -3.762883 3.647915   -4.160789 4.188215   -3.647915 3.762883
# sub-031 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-032 ses-1  -4.168122 4.849777   -3.738424 4.452260   -4.849777 4.168122
#         ses-2  -3.805796 3.450100   -4.504326 5.026884   -3.450100 3.805796
# sub-033 ses-1  -3.805919 3.537227   -3.207556 3.809199   -3.537227 3.805919
#         ses-2  -3.119466 3.208092   -3.937536 3.847660   -3.208092 3.119466
# sub-034 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-035 ses-1  -3.903433 5.159375   -4.110165 3.530245   -5.159375 3.903433
#         ses-2                  NaN                  NaN                  NaN
# sub-036 ses-1  -4.059270 3.917537   -4.772524 4.541537   -3.917537 4.059270
#         ses-2  -3.947780 4.093884   -3.810893 3.659480   -4.093884 3.947780
# sub-037 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-038 ses-1  -4.145282 4.245188   -4.287720 4.196820   -4.245188 4.145282
#         ses-2  -3.770903 3.418560   -4.487318 3.901685   -3.418560 3.770903
# sub-039 ses-1  -3.180256 3.353691   -3.808829 3.306648   -3.353691 3.180256
#         ses-2  -4.055908 4.139850   -3.845843 4.383324   -4.139850 4.055908
# sub-040 ses-1  -3.968064 4.425761   -3.750310 3.805756   -4.425761 3.968064
#         ses-2  -3.872738 4.288119   -3.496023 3.530360   -4.288119 3.872738
# sub-041 ses-1  -3.635098 3.445573   -4.001626 4.053974   -3.445573 3.635098
#         ses-2  -3.806318 4.250915   -4.254143 3.769802   -4.250915 3.806318
# sub-042 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-043 ses-1  -3.872168 4.373730   -4.295705 4.226437   -4.373730 3.872168
#         ses-2                  NaN                  NaN                  NaN
# sub-044 ses-1  -3.561976 3.728807   -3.185539 3.005183   -3.728807 3.561976
#         ses-2  -3.424110 3.241498   -4.432326 3.401548   -3.241498 3.424110
# sub-045 ses-1  -3.101794 3.888566   -4.189911 3.986956   -3.888566 3.101794
#         ses-2  -3.271412 4.153418   -4.314539 3.375446   -4.153418 3.271412
# sub-046 ses-1  -4.393920 3.320424   -4.134542 4.286812   -3.320424 4.393920
#         ses-2  -4.312420 3.855984   -3.814024 3.817535   -3.855984 4.312420
# sub-047 ses-1  -3.943992 4.207206   -3.643649 4.130506   -4.207206 3.943992
#         ses-2  -4.425879 4.021047   -3.721216 3.943290   -4.021047 4.425879
# sub-048 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-049 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-050 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-051 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-052 ses-1                  NaN                  NaN                  NaN
#         ses-2  -6.189584 5.212928   -4.810512 4.264005   -5.212928 6.189584
# sub-053 ses-1  -3.428132 3.249535   -4.078998 3.009969   -3.249535 3.428132
#         ses-2  -4.412055 3.920338   -3.314509 3.569544   -3.920338 4.412055
# sub-054 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-055 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
# sub-056 ses-1                  NaN                  NaN                  NaN
#         ses-2                  NaN                  NaN                  NaN
#
#               task-pe_run-2_zstat9
# sub-001 ses-1                  NaN
#         ses-2                  NaN
# sub-002 ses-1                  NaN
#         ses-2                  NaN
# sub-003 ses-1                  NaN
#         ses-2                  NaN
# sub-004 ses-1                  NaN
#         ses-2  -3.789935 4.443163
# sub-006 ses-1                  NaN
#         ses-2                  NaN
# sub-007 ses-1                  NaN
#         ses-2                  NaN
# sub-008 ses-1                  NaN
#         ses-2                  NaN
# sub-009 ses-1                  NaN
#         ses-2                  NaN
# sub-010 ses-1                  NaN
#         ses-2                  NaN
# sub-011 ses-1                  NaN
#         ses-2                  NaN
# sub-012 ses-1                  NaN
#         ses-2                  NaN
# sub-013 ses-1                  NaN
#         ses-2                  NaN
# sub-014 ses-1                  NaN
#         ses-2                  NaN
# sub-015 ses-1                  NaN
#         ses-2                  NaN
# sub-016 ses-1                  NaN
#         ses-2                  NaN
# sub-017 ses-1                  NaN
#         ses-2                  NaN
# sub-018 ses-1                  NaN
#         ses-2                  NaN
# sub-019 ses-1                  NaN
#         ses-2                  NaN
# sub-020 ses-1                  NaN
#         ses-2                  NaN
# sub-021 ses-1                  NaN
#         ses-2                  NaN
# sub-022 ses-1  -4.124205 4.792962
#         ses-2  -3.835413 3.790965
# sub-023 ses-1                  NaN
#         ses-2                  NaN
# sub-025 ses-1  -4.009985 3.977311
#         ses-2  -3.326349 3.440511
# sub-026 ses-1  -4.069550 3.847307
#         ses-2  -4.484983 5.204559
# sub-027 ses-1                  NaN
#         ses-2                  NaN
# sub-028 ses-1  -3.772550 4.166442
#         ses-2                  NaN
# sub-029 ses-1  -3.263979 4.480811
#         ses-2  -4.670918 3.639904
# sub-030 ses-1  -3.309891 4.433038
#         ses-2  -4.188215 4.160789
# sub-031 ses-1                  NaN
#         ses-2                  NaN
# sub-032 ses-1  -4.452260 3.738424
#         ses-2  -5.026884 4.504326
# sub-033 ses-1  -3.809199 3.207556
#         ses-2  -3.847660 3.937536
# sub-034 ses-1                  NaN
#         ses-2                  NaN
# sub-035 ses-1  -3.530245 4.110165
#         ses-2                  NaN
# sub-036 ses-1  -4.541537 4.772524
#         ses-2  -3.659480 3.810893
# sub-037 ses-1                  NaN
#         ses-2                  NaN
# sub-038 ses-1  -4.196820 4.287720
#         ses-2  -3.901685 4.487318
# sub-039 ses-1  -3.306648 3.808829
#         ses-2  -4.383324 3.845843
# sub-040 ses-1  -3.805756 3.750310
#         ses-2  -3.530360 3.496023
# sub-041 ses-1  -4.053974 4.001626
#         ses-2  -3.769802 4.254143
# sub-042 ses-1                  NaN
#         ses-2                  NaN
# sub-043 ses-1  -4.226437 4.295705
#         ses-2                  NaN
# sub-044 ses-1  -3.005183 3.185539
#         ses-2  -3.401548 4.432326
# sub-045 ses-1  -3.986956 4.189911
#         ses-2  -3.375446 4.314539
# sub-046 ses-1  -4.286812 4.134542
#         ses-2  -3.817535 3.814024
# sub-047 ses-1  -4.130506 3.643649
#         ses-2  -3.943290 3.721216
# sub-048 ses-1                  NaN
#         ses-2                  NaN
# sub-049 ses-1                  NaN
#         ses-2                  NaN
# sub-050 ses-1                  NaN
#         ses-2                  NaN
# sub-051 ses-1                  NaN
#         ses-2                  NaN
# sub-052 ses-1                  NaN
#         ses-2  -4.264005 4.810512
# sub-053 ses-1  -3.009969 4.078998
#         ses-2  -3.569544 3.314509
# sub-054 ses-1                  NaN
#         ses-2                  NaN
# sub-055 ses-1                  NaN
#         ses-2                  NaN
# sub-056 ses-1                  NaN
#         ses-2                  NaN

# %%
# helper function to color good values green in dataframe
def color_positive_green(val):
    #print(val)
    color = 'green' if val != "0.000000 0.000000 " and pd.isnull(val) != True else 'black'
    #if color == 'red':
     #   print(color)
    #return ['background-color: red' if v else '' for v in is_zero]
    return 'color: %s' % color

# %%
# split our dataframes into 2 session dataframes
#lvl1_zstat_df.loc(axis=0)[pd.IndexSlice[:, 'ses-1']]
ses1_zstat = lvl1_zstat_df.xs('ses-1',level=1)
ses2_zstat = lvl1_zstat_df.xs('ses-2', level=1)

# %%
## extract good subs here

# %%
# separate tasks
train_s2_zstat = ses2_zstat.filter(regex="training")
train_s1_zstat = ses1_zstat.filter(regex="training")
pe_s2_zstat = ses2_zstat.filter(regex="pe")
pe_s1_zstat = ses1_zstat.filter(regex="pe")
# color values
train_s1_zstat=train_s1_zstat.style.applymap(color_positive_green)
train_s2_zstat=train_s2_zstat.style.applymap(color_positive_green)
pe_s1_zstat=pe_s1_zstat.style.applymap(color_positive_green)
pe_s2_zstat=pe_s2_zstat .style.applymap(color_positive_green)

# %%
#train_s1_zstat

# %% [markdown]
# ### Write Files

# %%
train_s1_zstat.to_excel("reports/voxel_check.xlsx", sheet_name="ses-1_task-training_lvl1_voxel_check")

# %%
#lvl1_zstat_df.to_excel("expanded2.0_lvl1_copes_voxel_check.xlsx")
from openpyxl import load_workbook
    
file_name="/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code/reports/voxel_check.xlsx"
writer = pd.ExcelWriter(file_name, engine='openpyxl')

if os.path.exists(file_name):
    book = load_workbook(file_name)
    writer.book = book

train_s2_zstat.to_excel(writer, sheet_name="ses-2_task-training_lvl1_voxel_check")
pe_s1_zstat.to_excel(writer, sheet_name="ses-1_task-pe_lvl1_voxel_check")
pe_s2_zstat.to_excel(writer, sheet_name="ses-2_task-pe_lvl1_voxel_check")


writer.save()
writer.close()

# %% [markdown]
# ## Feat2

# %% [markdown]
# ### Skipping Registration:

# %%
import glob, os
from shutil import rmtree, copy2
from subprocess import call

# %%
base_path='/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed' #input("Enter your target study bids path:")
task="task-training"

# %%
def skip_registration(task, base_path):
    print('[INFO] skipping registration level1 directory mods for level2...')
    # loop through subjects
    feat_path = 'analysis/feat1/*pe_*.feat'
    for sub_path in glob.glob(os.path.join(base_path,"sub-*" )):
        sub_path = os.path.join(sub_path, "ses-1")
        print("[INFO] modifying subject path %s "%sub_path )
        # get .feat files for subject
        FEATS=glob.glob(os.path.join(sub_path,feat_path))
        # get .mat files for subject
        MAT_DIRS = glob.glob(os.path.join(sub_path, feat_path, "reg/*.mat"))
        # get reg_standard directories for subject
        REGSTD_DIRS = glob.glob(os.path.join(sub_path,feat_path, "reg_standard")) # reg_standard/ directories 

        # remove reg_standard directory
        if not REGSTD_DIRS:
            #print("--------------------------------------->>>> PASSING STEP 1")
            pass
        else:
            for dir_ in REGSTD_DIRS:
                print("[INFO] REMOVING REG_STANDARD DIRECTORY ", dir_)
                rmtree(dir_)

        # remove .mat files
        if not MAT_DIRS:
            #print("--------------------------------------->>>> PASSING STEP 2 PART A")
            pass
        else:
            for mat in MAT_DIRS:
                print("[INFO] REMOVING MAT FILES", mat)
                os.remove(mat)

        # copy identity matrix
        REG_PATHS = glob.glob(os.path.join(sub_path, "analysis/feat1/*.feat/reg"))
        for reg in REG_PATHS:
            path="%s/example_func2standard.mat"%reg
            copy_mat_cmd='cp $FSLDIR/etc/flirtsch/ident.mat %s'%path
            print("[INFO] COPYING IDENTITY MATRIX", copy_mat_cmd)
            os.system(copy_mat_cmd)

        # copy mean files 
        for feat in FEATS:        
            MEAN_PATH = os.path.join(feat, "mean_func.nii.gz")
            REG_DIR = os.path.join(feat, "reg", "standard.nii.gz")
            copy_mean_cmd = 'cp %s %s'%(MEAN_PATH, REG_DIR)
            print("[INFO] COPYING MEAN FILE ", copy_mean_cmd)
            os.system(copy_mean_cmd)

# %%
skip_registration(task, base_path)

# %% [markdown]
# ### Setup level 2 models

# %%
def writeDesignFile(DER_DIR, subID, feat1_folders,tempfsf, task, sess):
    outpath = os.path.join(DER_DIR,"preprocessed", subID,sess, "analysis/feat2/{}_{}_task-{}".format(subID,sess, task) )
    print("[INFO] writing outfiles for ... ",subID )
    tempfsf = tempfsf.replace("OUTPUT", outpath)
    #print(FEATS)
    i = 1
    for run_path in feat1_folders:
        #print(run_path)
        #run = run_path.split("/")[-1].split(".")[0].split("_")[1]
        run = "run%s"%i
        #print("> %s : %s"%(run, run_path))
        tempfsf = tempfsf.replace(run, run_path)
        i += 1
    #print(tempfsf)
    OUTFILE_PATH = os.path.join(DER_DIR, "preprocessed",subID,sess, "analysis/feat2/%s_%s_task-%s_design.fsf"%(subID, sess, task))
    #print("OUTFILE ------------------------>>>> ", OUTFILE_PATH)
    with open(OUTFILE_PATH, "w") as outfile:
        outfile.write(tempfsf)
    outfile.close()

# %%
def write_level2_files(task,sess, deriv_dir):
    print("[INFO] writing level2 model design files...")
    for sub_path in glob.glob(os.path.join(base_path, "sub-*" )):

        sub_id = sub_path.split("/")[-1]
        good_runs = 0
        feat1_folders= glob.glob(os.path.join(sub_path, sess,"analysis/feat1/*{}_*.feat".format(task)))

        for folder in feat1_folders:
            zstats=glob.glob(os.path.join(folder, "stats/cope*.nii.gz"))
            #print(zstats)
            if not zstats:
                #print("BAD FOLDER:\n", folder)
                pass
                #rmtree(folder)
            else:
                good_runs += 1

        # start analysis

        ### check for existence of feat2 directory
        FEAT2_DIR = os.path.join(sub_path,sess, "analysis/feat2")
        #print(FEAT2_DIR)
        if os.path.exists(FEAT2_DIR):
            pass
        else:
            os.makedirs(FEAT2_DIR)

        if good_runs == 2:
            with open(os.path.join(deriv_dir, "code/design_file_templates/design2_pe.fsf"), 'r') as infile:
                tempfsf=infile.read()
                writeDesignFile(deriv_dir, sub_id, feat1_folders, tempfsf, task, sess)
                infile.close()
        else:
            pass

# %%
deriv_dir='/projects/niblab/bids_projects/Experiments/bro/bids/derivatives'
sess='ses-1'
task = 'pe'

write_level2_files(task,sess,deriv_dir)
# Out:
# [INFO] writing level2 model design files...
# [INFO] writing outfiles for ...  sub-025
# [INFO] writing outfiles for ...  sub-028
# [INFO] writing outfiles for ...  sub-029
# [INFO] writing outfiles for ...  sub-030
# [INFO] writing outfiles for ...  sub-032
# [INFO] writing outfiles for ...  sub-033
# [INFO] writing outfiles for ...  sub-036
# [INFO] writing outfiles for ...  sub-038
# [INFO] writing outfiles for ...  sub-039
# [INFO] writing outfiles for ...  sub-040
# [INFO] writing outfiles for ...  sub-041
# [INFO] writing outfiles for ...  sub-045
# [INFO] writing outfiles for ...  sub-046
# [INFO] writing outfiles for ...  sub-047
# [INFO] writing outfiles for ...  sub-053
# [INFO] writing outfiles for ...  sub-035
# [INFO] writing outfiles for ...  sub-022
# [INFO] writing outfiles for ...  sub-026
# [INFO] writing outfiles for ...  sub-043

# %% [markdown]
# ### Submit batch jobs

# %%
def submit_slurm(sess, task, bash_file, run_cmd=False):
    print("[INFO] submitting slurm job...")
    
    df = df_dict[sess]
    good_subs = df[(df.T!=0).all()].index.values
    subject_set = sorted([int(x.split("-")[1].lstrip("0")) for x in good_subs])
    #print(subject_set)
    
    start = subject_set[0]
    end = subject_set[-1]
    #print(start, end)
    #for sub_num in subject_set:
    shell_cmd = "sbatch --array={}-{}%{} {} {} {}".format(start, end, len(subject_set), bash_file, sess, task)
    if run_cmd == True:
        print("[INFO] submitted job")
        os.system(shell_cmd)
    print("[INFO] BATCH COMMAND: ", shell_cmd)

# %%
sess='ses-2'
task = 'pe'

bash_file =os.path.join('/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code', 'feat2.job')
submit_slurm(sess,task, bash_file, run_cmd=True)
# Out:
# [INFO] submitting slurm job...
# [INFO] submitted job
# [INFO] BATCH COMMAND:  sbatch --array=4-53%23 /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code/feat2.job ses-2 pe

# %%
# !squeue -u nbytes
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
# 2950356_[42-53%23]     batch    f2bro   nbytes PD       0:00      1 (JobArrayTaskLimit)
#         2950356_29     batch    f2bro   nbytes  R       0:01      1 compute-7-9
#         2950356_30     batch    f2bro   nbytes  R       0:01      1 compute-0-12
#         2950356_32     batch    f2bro   nbytes  R       0:01      1 compute-0-15
#         2950356_33     batch    f2bro   nbytes  R       0:01      1 compute-0-23
#         2950356_36     batch    f2bro   nbytes  R       0:01      1 compute-0-24
#         2950356_38     batch    f2bro   nbytes  R       0:01      1 compute-4-26
#         2950356_39     batch    f2bro   nbytes  R       0:01      1 compute-0-19
#         2950356_40     batch    f2bro   nbytes  R       0:01      1 compute-0-28
#         2950356_41     batch    f2bro   nbytes  R       0:01      1 compute-4-31
#          2950356_4     batch    f2bro   nbytes  R       0:02      1 largemem-0-0
#         2950356_25     batch    f2bro   nbytes  R       0:02      1 compute-7-6
#         2950356_26     batch    f2bro   nbytes  R       0:02      1 compute-7-7
#         2950324_53     batch    f2bro   nbytes  R       0:06      1 largemem-0-0
#         2950324_22     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_25     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_26     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_28     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_29     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_30     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_32     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_33     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_35     batch    f2bro   nbytes  R       0:07      1 compute-8-15
#         2950324_36     batch    f2bro   nbytes  R       0:07      1 compute-0-0
#         2950324_38     batch    f2bro   nbytes  R       0:07      1 compute-0-3
#         2950324_39     batch    f2bro   nbytes  R       0:07      1 compute-0-4
#         2950324_40     batch    f2bro   nbytes  R       0:07      1 compute-0-6
#         2950324_41     batch    f2bro   nbytes  R       0:07      1 compute-0-7
#         2950324_43     batch    f2bro   nbytes  R       0:07      1 compute-0-1
#         2950324_45     batch    f2bro   nbytes  R       0:07      1 compute-0-11
#         2950324_46     batch    f2bro   nbytes  R       0:07      1 largemem-0-0
#         2950324_47     batch    f2bro   nbytes  R       0:07      1 compute-8-15
#         2950356_12     batch    f2bro   nbytes  S       0:00      1 compute-4-2
#         2950356_13     batch    f2bro   nbytes  S       0:00      1 compute-4-4
#         2950356_14     batch    f2bro   nbytes  S       0:00      1 compute-4-6
#         2950356_15     batch    f2bro   nbytes  S       0:00      1 compute-4-8
#         2950356_16     batch    f2bro   nbytes  S       0:00      1 compute-4-10
#         2950356_17     batch    f2bro   nbytes  S       0:00      1 compute-4-14
#         2950356_18     batch    f2bro   nbytes  S       0:00      1 compute-4-16
#         2950356_19     batch    f2bro   nbytes  S       0:00      1 compute-4-18
#         2950356_20     batch    f2bro   nbytes  S       0:00      1 compute-4-21
#         2950356_21     batch    f2bro   nbytes  S       0:00      1 compute-4-22
#         2950356_22     batch    f2bro   nbytes  S       0:00      1 compute-4-25

# %% [markdown]
# ### Quality Check

# %%
# helper function to generate qc level2 report
def qc_level2(base_path, task):
    for sess in ['ses-1', 'ses-2']:
        for sub_id in ses1_df.index.values:

            sub_dir = os.path.join(base_path, sub_id, sess)

            if sub_id not in qc_dict:
                qc_dict[sub_id] = {}
            if sub_id not in lvl2_zstat_dict:
                lvl2_zstat_dict[sub_id] = {}
            if sess not in lvl2_zstat_dict[sub_id]:
                lvl2_zstat_dict[sub_id][sess] = {}



            feat2_folder=os.path.join(sub_dir, 'analysis/feat2/{}_{}_{}.gfeat'.format(sub_id,sess, task))
            mean_func = os.path.join(feat2_folder,'mean_func.nii.gz')
            cope_folders= glob.glob(os.path.join(feat2_folder, "*.feat"))
            cope_folder_ct = len(cope_folders)
            zstat_files = glob.glob(os.path.join(feat2_folder, "*.feat/stats/zstat1.nii.gz"))
            zstat_file_ct = len(zstat_files)

            qc_dict[sub_id]["zstat_file_ct"] = zstat_file_ct
            qc_dict[sub_id]["cope_folder_ct"] = cope_folder_ct



            for zstat in sorted(zstat_files):
                cope=zstat.split("/")[-3].split(".")[0]
                #print(cope)
                cmd='fslstats %s -R'%zstat

                process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
                output, error = process.communicate()              

                output=output.decode("utf-8")
                output=output.strip("\n")
                lvl2_zstat_dict[sub_id][sess][cope] = output





        df=pd.DataFrame(qc_dict).T
        print("[INFO] session: %s \t%s "%(sess,task))
        print("[INFO] good subject count: %s \n"%len(df[(df.T !=0).all()].index.values))
        #display(df)
        lvl2_df_dict[sess] = df

# %%
qc_dict={}
lvl2_df_dict ={}
mean_func_ct=0
lvl2_zstat_dict={}
subjects_with_0s = []
task="task-pe"
qc_level2(base_path,task="task-pe")
# Out:
# [INFO] session: ses-1 	task-pe
# [INFO] good subject count: 19
#
# [INFO] session: ses-2 	task-pe
# [INFO] good subject count: 19

# %%
lvl2_zstat_df =pd.concat({k: pd.DataFrame(v).T for k, v in lvl2_zstat_dict.items()}, axis=0, sort=True)
#lvl2_zstat_df = lvl2_zstat_df.fillna(0)

# %%
print("[INFO] %s : zstat voxel check report..."%task)
lvl2_zstat_df.style.applymap(color_positive_green)
# Out:
# [INFO] task-pe : zstat voxel check report...
# <style  type="text/css" >
#     #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col2 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col3 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col4 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col5 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col6 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col7 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col8 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col9 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col10 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col11 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col12 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col13 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col14 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col15 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow0_col16 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col2 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col3 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col4 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col5 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col6 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col7 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col8 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col9 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col10 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col11 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col12 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col13 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col14 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col15 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow1_col16 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col2 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col3 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col4 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col5 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col6 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col7 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col8 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col9 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col10 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col11 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col12 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col13 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col14 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col15 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow2_col16 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col2 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col3 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col4 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col5 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col6 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col7 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col8 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col9 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col10 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col11 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col12 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col13 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col14 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col15 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow3_col16 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col2 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col3 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col4 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col5 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col6 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col7 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col8 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col9 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col10 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col11 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col12 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col13 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col14 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col15 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow4_col16 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow5_col0 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_11ea_b26e_005056a236fcrow5_col1 {
#             color:  black;
#         }    #T_7e55c7d0_7fa0_1

# %% [markdown]
# ### Setup level 3 models

# %%
# helper function to write model3 design files
def write_lvl3_designs(folder, template, sub_ct, cope_ct, cope_dict, sess, task):
    deriv_dir = folder
    template_file = template
    # get the number of cope files to make (# of copes)
    num_of_copes = cope_ct
    num_of_input = sub_ct
    #print(num_of_copes)
    
    # loop through copes and make design file for each
    for cope_num in range(1, num_of_copes+1):
        
        if cope_num not in cope_dict:
            cope_dict[cope_num] = {}
            
        #OUTPUTDIR = os.path.join(deriv_dir, 'group_ana/cope%s_ses-1'%cope_num)
        OUTPUTDIR = os.path.join(deriv_dir, 'preprocessed/group_analysis/%s/%s_task-%s_cope%s'%(task.split('-')[1],sess,task, cope_num))

        COPES = glob.glob(os.path.join(deriv_dir, "preprocessed", "sub-*",sess,'analysis/feat2/sub-*%s*gfeat/cope%s.feat'%(task,cope_num)))
        COPES = sorted(COPES)
        
        
        for x,cope in enumerate(COPES):
            
            count=int(x)+1
            if count > 9:
                INPUTX = "INPUT_%i"%(count)
            else:
                INPUTX = "INPUT%i"%(count)
            cope_dict[cope_num][INPUTX] = cope
            #print("%s >>>>-----> %s"%(INPUTX,cope))
        with open(template_file, 'r') as infile:
            tempfsf=infile.read()
            tempfsf = tempfsf.replace("OUTPUT", OUTPUTDIR)
            for input_title in sorted(cope_dict[cope_num]):
                input_ = cope_dict[cope_num][input_title]
                tempfsf = tempfsf.replace("%s"%input_title, input_)
            OUTFILE_PATH = os.path.join(deriv_dir, 'preprocessed/group_analysis/%s/%s_%s_cope%s.fsf'%(task.split('-')[1],sess,task,cope_num))
            #print(tempfsf)
            print("[INFO] writing output file...", OUTFILE_PATH)
            if not os.path.exists(os.path.join(deriv_dir, 'preprocessed/group_analysis/%s'%task.split('-')[1])):
                os.makedirs(os.path.join(deriv_dir, 'preprocessed/group_analysis/%s'%task.split('-')[1]))
                
            with open(OUTFILE_PATH, 'w') as outfile:
                outfile.write(tempfsf)
            outfile.close()
        infile.close()

# %%
def write_design_files():
    
    sess = 'ses-1'
    task='task-pe'
    cope_dict = {}
    base_folder = '/projects/niblab/bids_projects/Experiments/bro/bids/derivatives'
    template_fsf = '/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code/model_designs/design3.19.fsf'
    sub_ct = 19
    cope_ct = 17
    
    
    print("[INFO] ses: %s subject count: %s task: %s \tcope count: %s"%(sess,sub_ct, task,cope_ct))
    write_lvl3_designs(base_folder, template_fsf, sub_ct, cope_ct, cope_dict,sess, task)
    
    
cope_ct=17

write_design_files()
# Out:
# [INFO] ses: ses-1 subject count: 19 task: task-pe 	cope count: 17
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope1.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope2.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope3.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope4.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope5.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope6.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope7.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope8.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope9.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope10.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope11.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope12.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope13.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope14.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope15.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope16.fsf
# [INFO] writing output file... /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/pe/ses-1_task-pe_cope17.fsf

# %%
def run_lvl3_models(task,sess, cope_ct, run_cmd=False):
    task=task.split('-')[1]
    sess=sess.split('-')[1]
    
    # for ses-1
    bash_file = os.path.join('/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code', 'feat3.job') 
    start = 1
    end = cope_ct

    shell_cmd = "sbatch --array={}-{}%{} {} {} {}".format(start, end, end, bash_file, sess, task)
    if run_cmd == True:
        os.system(shell_cmd)
    print("[INFO] running command ... %s"%shell_cmd)

# %%
cope_ct=17
sess="ses-2"
task="task-pe"
run_lvl3_slurm(task,sess, cope_ct, True)
# Out:
# [INFO] running command ... sbatch --array=1-17%17 /projects/niblab/bids_projects/Experiments/bro/bids/derivatives/code/feat3.job 2 pe

# %%
# !squeue -u nbytes
# Out:
#              JOBID PARTITION     NAME     USER ST       TIME  NODES NODELIST(REASON)
#          2950475_1     batch    F3bro   nbytes  R       0:10      1 compute-0-0
#          2950475_2     batch    F3bro   nbytes  R       0:10      1 compute-0-1
#          2950475_3     batch    F3bro   nbytes  R       0:10      1 compute-0-3
#          2950475_4     batch    F3bro   nbytes  R       0:10      1 compute-0-4
#          2950475_5     batch    F3bro   nbytes  R       0:10      1 compute-0-6
#          2950475_6     batch    F3bro   nbytes  R       0:10      1 compute-0-7
#          2950475_7     batch    F3bro   nbytes  R       0:10      1 compute-0-11
#          2950475_8     batch    F3bro   nbytes  R       0:10      1 compute-0-12
#          2950475_9     batch    F3bro   nbytes  R       0:10      1 compute-0-15
#         2950475_10     batch    F3bro   nbytes  R       0:10      1 compute-0-19
#         2950475_11     batch    F3bro   nbytes  R       0:10      1 compute-0-23
#         2950475_12     batch    F3bro   nbytes  R       0:10      1 compute-0-24
#         2950475_13     batch    F3bro   nbytes  R       0:10      1 compute-0-28
#         2950475_14     batch    F3bro   nbytes  R       0:10      1 compute-1-0
#         2950475_15     batch    F3bro   nbytes  R       0:10      1 compute-1-1
#         2950475_16     batch    F3bro   nbytes  R       0:10      1 compute-1-2
#         2950475_17     batch    F3bro   nbytes  R       0:10      1 compute-1-3
#          2950458_1     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_2     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_3     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_4     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_5     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_6     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_7     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_8     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#          2950458_9     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#         2950458_10     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#         2950458_11     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#         2950458_12     batch    F3bro   nbytes  R       0:22      1 largemem-0-0
#         2950458_13     batch    F3bro   nbytes  R       0:22      1 compute-8-15
#         2950458_14     batch    F3bro   nbytes  R       0:22      1 compute-8-15
#         2950458_15     batch    F3bro   nbytes  R       0:22      1 compute-4-29
#         2950458_16     batch    F3bro   nbytes  R       0:22      1 compute-4-30
#         2950458_17     batch    F3bro   nbytes  R       0:22      1 compute-4-31

# %% [markdown]
# ### Quality Check level 3

# %%
def qc_lvl3_models(task):
    task=task.split("-")[1]
    for cope_dir in glob.glob('/projects/niblab/bids_projects/Experiments/bro/bids/derivatives/preprocessed/group_analysis/%s/*.gfeat'%task):
        #es-2_task-training_cope10.gfeat
        sess_id=cope_dir.split("/")[-1].split(".")[0].split("_")[0]
        cope_id=cope_dir.split("/")[-1].split(".")[0].split("_")[2]
        if cope_id not in qc_dict:
            qc_dict[cope_id] = {}
        #print(cope_id)
        if sess_id not in lvl3_dict:
            lvl3_dict[sess_id] = {}
        if cope_id not in lvl3_dict[sess_id]:
            lvl3_dict[sess_id][cope_id] = {}


        stats_folder=glob.glob(os.path.join(cope_dir, 'cope1.feat/stats/*'))
        if not stats_folder:
            print("MISSING")

        zstat_file_ct = len(stats_folder)

        qc_dict[cope_id]["zstat_file_ct"] = zstat_file_ct

        zstat_files = glob.glob(os.path.join(cope_dir, "cope1.feat/stats/zstat1.nii.gz"))
        zstat_file_ct = len(zstat_files)

        for zstat in sorted(zstat_files):
            cope=zstat.split("/")[-4].split(".")[0]
            #print(cope)

            cmd='fslstats %s -R'%zstat
            #voxel_intensity = stats.run()
            #output = list(stats.aggregate_outputs()
            process = subprocess.Popen(cmd.split(), stdout=subprocess.PIPE)
            output, error = process.communicate()              

            output=output.decode("utf-8")
            output=output.strip("\n")

            lvl3_dict[sess_id][cope_id]['zstat'] = output

# %%
for task in ['task-pe', 'task-training']:
    mean_func_ct=0
    qc_dict={}
    lvl3_dict={}
    qc_lvl3_models(task)
    print("[INFO] %s \n[INFO] Voxel check from zstat files in the level 3 models"%(task))
    lvl3_zstat_df =pd.concat({k: pd.DataFrame(v).T for k, v in lvl3_dict.items()}, axis=0, sort=True)
    display(lvl3_zstat_df.T)
# Out:
# [INFO] task-pe
# [INFO] Voxel check from zstat files in the level 3 models
#                      ses-1                                            \
#                     cope15               cope16               cope17
# zstat  -6.852843 5.401256   -3.081025 3.459982   -2.939416 3.236789
#
#                                                                       \
#                     cope13               cope14                cope1
# zstat  -2.829524 2.652389   -3.321151 2.687091   -3.279552 3.109510
#
#                                                                       \
#                      cope2                cope3                cope4
# zstat  -3.213049 3.069424   -3.794251 3.813819   -2.653368 2.829780
#
#                                                                       \
#                      cope6                cope9                cope8
# zstat  -3.106179 3.186391   -2.653368 3.313399   -3.186391 3.106179
#
#                                                                       \
#                      cope5               cope10                cope7
# zstat  -5.643332 5.208662   -3.774555 3.777668   -3.313399 2.653368
#
#                                                                ses-2  \
#                     cope11               cope12                cope1
# zstat  -2.830132 2.654551   -2.889757 3.431960   -2.822291 3.465023
#
#                                                                       \
#                      cope2                cope3                cope4
# zstat  -2.919338 3.543251   -3.056975 3.786303   -3.070341 3.166232
#
#                                                                       \
#                      cope5                cope6                cope7
# zstat  -5.491108 3.898543   -2.811543 3.589213   -3.166231 3.070340
#
#                                                                       \
#                      cope8                cope9               cope10
# zstat  -3.589213 2.811543   -3.070340 3.166231   -2.975651 3.945512
#
#                                                                       \
#                     cope11               cope12               cope13
# zstat  -3.166168 3.070173   -3.070332 3.166228   -3.166547 3.070489
#
#                                                                       \
#                     cope14               cope15               cope16
# zstat  -3.166198 3.070252   -8.283455 4.488976   -3.070317 3.166216
#
#
#                     cope17
# zstat  -3.234330 5.718135
# [INFO] task-training
# [INFO] Voxel check from zstat files in the level 3 models
#                      ses-1                                            \
#                     cope10                cope1                cope2
# zstat  -3.539954 5.231525   -4.002584 5.274480   -4.290170 3.583143
#
#                                                                       \
#                      cope3                cope4                cope5
# zstat  -3.799652 5.483512   -4.685711 2.883127   -4.988431 5.323785
#
#                                                                       \
#                      cope6                cope7                cope8
# zstat  -4.024570 3.257300   -3.407811 4.069576   -3.257300 4.024570
#
#                                           ses-2                       \
#                      cope9               cope10                cope1
# zstat  -4.069576 3.407811   -3.680752 4.597322   -3.729415 4.385585
#
#                                                                       \
#                      cope2                cope3                cope4
# zstat  -3.914823 3.175563   -3.938979 4.411117   -3.435974 3.141903
#
#                                                                       \
#                      cope5                cope6                cope7
# zstat  -4.380487 4.930459   -3.215672 3.609460   -3.337725 3.250712
#
#
#                      cope8                cope9
# zstat  -3.609460 3.215672   -3.250712 3.337725
